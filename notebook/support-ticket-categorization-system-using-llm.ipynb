# %% [markdown]
# ## **Problem Statement**

# %% [markdown]
# ### Business Context

# %% [markdown]
# In today's dynamic business landscape, organizations are increasingly recognizing the pivotal role customer feedback plays in shaping the trajectory of their products and services. The ability to swiftly and effectively respond to customer input not only fosters enhanced customer experiences but also serves as a catalyst for growth, prolonged customer engagement, and the nurturing of lifetime value relationships. As a dedicated Product Manager or Product Analyst, staying attuned to the voice of your customers is not just a best practice; it's a strategic imperative.
#
# While your organization may be inundated with a wealth of customer-generated feedback and support tickets, your role entails much more than just processing these inputs. To make your efforts in managing customer experience and expectations truly impactful, you need a structured approach – a method that allows you to discern the most pressing issues, set priorities, and allocate resources judiciously. One of the most effective strategies at your disposal is to harness the power of Support Ticket Categorization.

# %% [markdown]
# ### Objective

# %% [markdown]
# Develop an advanced support ticket categorization system that accurately classifies incoming tickets, assigns relevant tags based on their content, implements mechanisms and generate the first response based on the sentiment for prioritizing tickets for prompt resolution.

# %% [markdown]
# ## **Installing and Importing Necessary Libraries and Dependencies**

# %%
# Installation for GPU llama-cpp-python
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install llama-cpp-python==0.1.85 --force-reinstall --no-cache-dir -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.8.3 requires cubinlinker, which is not installed.
# cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires ptxcompiler, which is not installed.
# cuml 24.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# ucxx 0.39.1 requires libucx>=1.15.0, which is not installed.
# apache-beam 2.46.0 requires cloudpickle~=2.2.1, but you have cloudpickle 3.0.0 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 2.1.2 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 16.1.0 which is incompatible.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# bigframes 0.22.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.2 which is incompatible.
# catboost 1.2.7 requires numpy<2.0,>=1.16.0, but you have numpy 2.1.2 which is incompatible.
# cudf 24.8.3 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# cudf 24.8.3 requires numpy<2.0a0,>=1.23, but you have numpy 2.1.2 which is incompatible.
# dask-cuda 24.8.2 requires numpy<2.0a0,>=1.23, but you have numpy 2.1.2 which is incompatible.
# dask-cudf 24.8.3 requires numpy<2.0a0,>=1.23, but you have numpy 2.1.2 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.9.2 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.1.2 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.14.1 which is incompatible.
# ibis-framework 7.1.0 requires numpy<2,>=1, but you have numpy 2.1.2 which is incompatible.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 16.1.0 which is incompatible.
# jupyterlab 4.2.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# matplotlib 3.7.5 requires numpy<2,>=1.20, but you have numpy 2.1.2 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.1.2 which is incompatible.
# pylibraft 24.8.1 requires numpy<2.0a0,>=1.23, but you have numpy 2.1.2 which is incompatible.
# raft-dask 24.8.1 requires numpy<2.0a0,>=1.23, but you have numpy 2.1.2 which is incompatible.
# rmm 24.8.2 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# rmm 24.8.2 requires numpy<2.0a0,>=1.23, but you have numpy 2.1.2 which is incompatible.
# tensorflow 2.16.1 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.1.2 which is incompatible.
# tensorflow-transform 0.14.0 requires numpy<2,>=1.16, but you have numpy 2.1.2 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.1.2 which is incompatible.
# ucx-py 0.39.2 requires numpy<2.0a0,>=1.23, but you have numpy 2.1.2 which is incompatible.
# ucxx 0.39.1 requires numpy<2.0a0,>=1.23, but you have numpy 2.1.2 which is incompatible.
# xarray 2024.9.0 requires packaging>=23.1, but you have packaging 21.3 which is incompatible.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.

# %%
# For downloading the models from HF Hub
# !pip install huggingface_hub==0.20.3 pandas==1.5.3 -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.8.3 requires cubinlinker, which is not installed.
# cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires ptxcompiler, which is not installed.
# cuml 24.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# accelerate 0.34.2 requires huggingface-hub>=0.21.0, but you have huggingface-hub 0.20.3 which is incompatible.
# beatrix-jupyterlab 2024.66.154055 requires jupyterlab~=3.6.0, but you have jupyterlab 4.2.5 which is incompatible.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# catboost 1.2.7 requires numpy<2.0,>=1.16.0, but you have numpy 2.1.2 which is incompatible.
# cudf 24.8.3 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# cudf 24.8.3 requires numpy<2.0a0,>=1.23, but you have numpy 2.1.2 which is incompatible.
# cudf 24.8.3 requires pandas<2.2.3dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# dask-cuda 24.8.2 requires numpy<2.0a0,>=1.23, but you have numpy 2.1.2 which is incompatible.
# dask-cudf 24.8.3 requires numpy<2.0a0,>=1.23, but you have numpy 2.1.2 which is incompatible.
# dask-cudf 24.8.3 requires pandas<2.2.3dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# dask-expr 1.1.15 requires pandas>=2, but you have pandas 1.5.3 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.9.2 which is incompatible.
# datasets 3.0.1 requires huggingface-hub>=0.22.0, but you have huggingface-hub 0.20.3 which is incompatible.
# featuretools 1.31.0 requires pandas>=2.0.0, but you have pandas 1.5.3 which is incompatible.
# ibis-framework 7.1.0 requires numpy<2,>=1, but you have numpy 2.1.2 which is incompatible.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 16.1.0 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# mizani 0.11.4 requires pandas>=2.1.0, but you have pandas 1.5.3 which is incompatible.
# plotnine 0.13.6 requires pandas<3.0.0,>=2.1.0, but you have pandas 1.5.3 which is incompatible.
# pyldavis 3.4.1 requires pandas>=2.0.0, but you have pandas 1.5.3 which is incompatible.
# raft-dask 24.8.1 requires numpy<2.0a0,>=1.23, but you have numpy 2.1.2 which is incompatible.
# rapids-dask-dependency 24.8.0a0 requires dask==2024.7.1, but you have dask 2024.9.1 which is incompatible.
# transformers 4.45.1 requires huggingface-hub<1.0,>=0.23.2, but you have huggingface-hub 0.20.3 which is incompatible.
# woodwork 0.31.0 requires pandas>=2.0.0, but you have pandas 1.5.3 which is incompatible.
# xarray 2024.9.0 requires packaging>=23.1, but you have packaging 21.3 which is incompatible.
# xarray 2024.9.0 requires pandas>=2.1, but you have pandas 1.5.3 which is incompatible.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.

# %%
# Function to download the model from the Hugging Face model hub
from huggingface_hub import hf_hub_download

# Importing the Llama class from the llama_cpp module
from llama_cpp import Llama

# Importing the json module
import json

# for loading and manipulating data
import pandas as pd

# for time computations
import time
# Out:
# ggml_init_cublas: found 2 CUDA devices:
#   Device 0: Tesla T4, compute capability 7.5
#   Device 1: Tesla T4, compute capability 7.5

# %% [markdown]
# ## **Loading the Data**

# %%
# reading the CSV file.
data = pd.read_csv("/kaggle/input/customer-support-nlp-dataset/support_ticket_data.csv")

# %% [markdown]
# ## **Data Overview**

# %% [markdown]
# ### Checking the first 5 rows of the data

# %%
data.head()
# Out:
#   support_tick_id                                support_ticket_text
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...

# %% [markdown]
# ### Checking the shape of the data

# %%
data.shape
# Out:
# (21, 2)

# %% [markdown]
# ### Checking the missing values in the data

# %%
data.isnull().sum()
# Out:
# support_tick_id        0
# support_ticket_text    0
# dtype: int64

# %% [markdown]
# ## **Model Building**

# %% [markdown]
# ### Loading the model

# %%
model_name_or_path = "TheBloke/Mistral-7B-Instruct-v0.2-GGUF"
model_basename = "mistral-7b-instruct-v0.2.Q6_K.gguf"

# %%
model_path = hf_hub_download(
    repo_id=model_name_or_path, 
    filename=model_basename  
)
# Out:
# mistral-7b-instruct-v0.2.Q6_K.gguf:   0%|          | 0.00/5.94G [00:00<?, ?B/s]

# %%
llm = Llama(
    model_path=model_path,
    n_ctx=1024, # Context window
)
# Out:
# llama_model_loader: loaded meta data with 24 key-value pairs and 291 tensors from /root/.cache/huggingface/hub/models--TheBloke--Mistral-7B-Instruct-v0.2-GGUF/snapshots/3a6fbf4a41a1d52e415a4958cde6856d34b2db93/mistral-7b-instruct-v0.2.Q6_K.gguf (version unknown)
# llama_model_loader: - tensor    0:                token_embd.weight q6_K     [  4096, 32000,     1,     1 ]
# llama_model_loader: - tensor    1:              blk.0.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    2:              blk.0.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor    3:              blk.0.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor    4:         blk.0.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    5:            blk.0.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor    6:              blk.0.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor    7:            blk.0.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor    8:           blk.0.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor    9:            blk.0.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   10:              blk.1.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   11:              blk.1.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   12:              blk.1.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   13:         blk.1.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   14:            blk.1.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   15:              blk.1.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   16:            blk.1.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   17:           blk.1.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   18:            blk.1.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   19:              blk.2.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   20:              blk.2.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   21:              blk.2.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   22:         blk.2.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   23:            blk.2.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   24:              blk.2.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   25:            blk.2.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   26:           blk.2.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   27:            blk.2.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   28:              blk.3.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   29:              blk.3.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   30:              blk.3.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   31:         blk.3.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   32:            blk.3.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   33:              blk.3.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   34:            blk.3.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   35:           blk.3.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   36:            blk.3.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   37:              blk.4.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   38:              blk.4.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   39:              blk.4.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   40:         blk.4.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   41:            blk.4.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   42:              blk.4.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   43:            blk.4.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   44:           blk.4.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   45:            blk.4.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   46:              blk.5.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   47:              blk.5.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   48:              blk.5.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   49:         blk.5.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   50:            blk.5.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   51:              blk.5.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   52:            blk.5.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   53:           blk.5.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   54:            blk.5.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   55:              blk.6.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   56:              blk.6.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   57:              blk.6.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   58:         blk.6.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   59:            blk.6.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   60:              blk.6.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   61:            blk.6.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   62:           blk.6.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   63:            blk.6.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   64:              blk.7.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   65:              blk.7.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   66:              blk.7.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   67:         blk.7.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   68:            blk.7.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   69:              blk.7.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   70:            blk.7.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   71:           blk.7.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   72:            blk.7.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   73:              blk.8.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   74:              blk.8.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   75:              blk.8.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   76:         blk.8.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   77:            blk.8.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   78:              blk.8.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   79:            blk.8.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   80:           blk.8.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   81:            blk.8.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   82:              blk.9.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   83:              blk.9.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   84:              blk.9.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   85:         blk.9.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   86:            blk.9.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   87:              blk.9.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   88:            blk.9.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   89:           blk.9.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   90:            blk.9.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   91:             blk.10.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   92:             blk.10.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   93:             blk.10.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   94:        blk.10.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   95:           blk.10.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   96:             blk.10.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   97:           blk.10.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   98:          blk.10.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   99:           blk.10.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  100:             blk.11.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  101:             blk.11.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  102:             blk.11.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  103:        blk.11.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  104:           blk.11.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  105:             blk.11.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  106:           blk.11.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  107:          blk.11.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  108:           blk.11.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  109:             blk.12.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  110:             blk.12.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  111:             blk.12.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  112:        blk.12.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  113:           blk.12.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  114:             blk.12.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  115:           blk.12.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  116:          blk.12.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  117:           blk.12.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  118:             blk.13.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  119:             blk.13.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  120:             blk.13.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  121:        blk.13.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  122:           blk.13.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  123:             blk.13.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  124:           blk.13.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  125:          blk.13.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  126:           blk.13.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  127:             blk.14.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  128:             blk.14.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  129:             blk.14.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  130:        blk.14.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  131:           blk.14.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  132:             blk.14.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  133:           blk.14.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  134:          blk.14.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  135:           blk.14.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  136:             blk.15.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  137:             blk.15.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  138:             blk.15.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  139:        blk.15.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  140:           blk.15.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  141:             blk.15.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  142:           blk.15.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  143:          blk.15.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  144:           blk.15.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  145:             blk.16.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  146:             blk.16.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  147:             blk.16.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  148:        blk.16.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  149:           blk.16.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  150:             blk.16.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  151:           blk.16.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  152:          blk.16.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  153:           blk.16.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  154:             blk.17.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  155:             blk.17.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  156:             blk.17.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  157:        blk.17.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  158:           blk.17.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  159:             blk.17.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  160:           blk.17.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  161:          blk.17.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  162:           blk.17.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  163:             blk.18.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  164:             blk.18.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  165:             blk.18.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  166:        blk.18.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  167:           blk.18.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  168:             blk.18.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  169:           blk.18.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  170:          blk.18.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  171:           blk.18.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  172:             blk.19.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  173:             blk.19.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  174:             blk.19.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  175:        blk.19.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  176:           blk.19.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  177:             blk.19.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  178:           blk.19.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  179:          blk.19.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  180:           blk.19.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  181:             blk.20.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  182:             blk.20.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  183:             blk.20.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  184:        blk.20.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  185:           blk.20.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  186:             blk.20.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  187:           blk.20.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  188:          blk.20.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  189:           blk.20.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  190:             blk.21.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  191:             blk.21.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  192:             blk.21.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  193:        blk.21.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  194:           blk.21.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  195:             blk.21.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  196:           blk.21.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  197:          blk.21.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  198:           blk.21.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  199:             blk.22.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  200:             blk.22.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  201:             blk.22.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  202:        blk.22.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  203:           blk.22.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  204:             blk.22.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  205:           blk.22.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  206:          blk.22.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  207:           blk.22.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  208:             blk.23.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  209:             blk.23.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  210:             blk.23.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  211:        blk.23.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  212:           blk.23.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  213:             blk.23.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  214:           blk.23.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  215:          blk.23.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  216:           blk.23.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  217:             blk.24.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  218:             blk.24.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  219:             blk.24.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  220:        blk.24.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  221:           blk.24.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  222:             blk.24.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  223:           blk.24.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  224:          blk.24.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  225:           blk.24.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  226:             blk.25.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  227:             blk.25.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  228:             blk.25.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  229:        blk.25.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  230:           blk.25.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  231:             blk.25.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  232:           blk.25.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  233:          blk.25.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  234:           blk.25.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  235:             blk.26.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  236:             blk.26.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  237:             blk.26.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  238:        blk.26.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  239:           blk.26.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  240:             blk.26.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  241:           blk.26.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  242:          blk.26.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  243:           blk.26.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  244:             blk.27.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  245:             blk.27.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  246:             blk.27.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  247:        blk.27.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  248:           blk.27.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  249:             blk.27.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  250:           blk.27.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  251:          blk.27.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  252:           blk.27.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  253:             blk.28.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  254:             blk.28.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  255:             blk.28.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  256:        blk.28.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  257:           blk.28.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  258:             blk.28.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  259:           blk.28.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  260:          blk.28.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  261:           blk.28.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  262:             blk.29.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  263:             blk.29.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  264:             blk.29.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  265:        blk.29.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  266:           blk.29.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  267:             blk.29.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  268:           blk.29.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  269:          blk.29.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  270:           blk.29.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  271:             blk.30.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  272:             blk.30.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  273:             blk.30.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  274:        blk.30.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  275:           blk.30.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  276:             blk.30.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  277:           blk.30.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  278:          blk.30.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  279:           blk.30.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  280:             blk.31.attn_q.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  281:             blk.31.attn_k.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  282:             blk.31.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  283:        blk.31.attn_output.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  284:           blk.31.ffn_gate.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  285:             blk.31.ffn_up.weight q6_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  286:           blk.31.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  287:          blk.31.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  288:           blk.31.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  289:               output_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  290:                    output.weight q6_K     [  4096, 32000,     1,     1 ]
# llama_model_loader: - kv   0:                       general.architecture str
# llama_model_loader: - kv   1:                               general.name str
# llama_model_loader: - kv   2:                       llama.context_length u32
# llama_model_loader: - kv   3:                     llama.embedding_length u32
# llama_model_loader: - kv   4:                          llama.block_count u32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32
# llama_model_loader: - kv   7:                 llama.attention.head_count u32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32
# llama_model_loader: - kv  10:                       llama.rope.freq_base f32
# llama_model_loader: - kv  11:                          general.file_type u32
# llama_model_loader: - kv  12:                       tokenizer.ggml.model str
# llama_model_loader: - kv  13:                      tokenizer.ggml.tokens arr
# llama_model_loader: - kv  14:                      tokenizer.ggml.scores arr
# llama_model_loader: - kv  15:                  tokenizer.ggml.token_type arr
# llama_model_loader: - kv  16:                tokenizer.ggml.bos_token_id u32
# llama_model_loader: - kv  17:                tokenizer.ggml.eos_token_id u32
# llama_model_loader: - kv  18:            tokenizer.ggml.unknown_token_id u32
# llama_model_loader: - kv  19:            tokenizer.ggml.padding_token_id u32
# llama_model_loader: - kv  20:               tokenizer.ggml.add_bos_token bool
# llama_model_loader: - kv  21:               tokenizer.ggml.add_eos_token bool
# llama_model_loader: - kv  22:                    tokenizer.chat_template str
# llama_model_loader: - kv  23:               general.quantization_version u32
# llama_model_loader: - type  f32:   65 tensors
# llama_model_loader: - type q6_K:  226 tensors
# llm_load_print_meta: format         = unknown
# llm_load_print_meta: arch           = llama
# llm_load_print_meta: vocab type     = SPM
# llm_load_print_meta: n_vocab        = 32000
# llm_load_print_meta: n_merges       = 0
# llm_load_print_meta: n_ctx_train    = 32768
# llm_load_print_meta: n_ctx          = 1024
# llm_load_print_meta: n_embd         = 4096
# llm_load_print_meta: n_head         = 32
# llm_load_print_meta: n_head_kv      = 8
# llm_load_print_meta: n_layer        = 32
# llm_load_print_meta: n_rot          = 128
# llm_load_print_meta: n_gqa          = 4
# llm_load_print_meta: f_norm_eps     = 1.0e-05
# llm_load_print_meta: f_norm_rms_eps = 1.0e-05
# llm_load_print_meta: n_ff           = 14336
# llm_load_print_meta: freq_base      = 1000000.0
# llm_load_print_meta: freq_scale     = 1
# llm_load_print_meta: model type     = 7B
# llm_load_print_meta: model ftype    = mostly Q6_K
# llm_load_print_meta: model size     = 7.24 B
# llm_load_print_meta: general.name   = mistralai_mistral-7b-instruct-v0.2
# llm_load_print_meta: BOS token = 1 '<s>'
# llm_load_print_meta: EOS token = 2 '</s>'
# llm_load_print_meta: UNK token = 0 '<unk>'
# llm_load_print_meta: PAD token = 0 '<unk>'
# llm_load_print_meta: LF token  = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size =    0.09 MB
# llm_load_tensors: using CUDA for GPU acceleration
# ggml_cuda_set_main_device: using device 0 (Tesla T4) as main device
# llm_load_tensors: mem required  = 5666.19 MB (+  128.00 MB per state)
# llm_load_tensors: offloading 0 repeating layers to GPU
# llm_load_tensors: offloaded 0/35 layers to GPU
# llm_load_tensors: VRAM used: 0 MB
# ...................................................................................................
# llama_new_context_with_model: kv self size  =  128.00 MB
# llama_new_context_with_model: compute buffer total size =   89.47 MB
# llama_new_context_with_model: VRAM scratch buffer: 88.00 MB
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %% [markdown]
# ### Utility functions

# %%
# defining a function to parse the JSON output from the model
def extract_json_data(json_str):
    try:
        # Find the indices of the opening and closing curly braces
        json_start = json_str.find('{')
        json_end = json_str.rfind('}')

        if json_start != -1 and json_end != -1:
            extracted_category = json_str[json_start:json_end + 1]  # Extract the JSON object
            data_dict = json.loads(extracted_category)
            return data_dict
        else:
            print(f"Warning: JSON object not found in response: {json_str}")
            return {}
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON: {e}")
        return {}

# %% [markdown]
# ## **Task 1: Ticket Categorization and Returning Structured Output**

# %%
data_1 = data.copy()

# %%
#Defining the response funciton for Task 1.
def response_1(prompt,ticket):
    model_output = llm(
      f"""
      Q: {prompt}
      Support ticket: {ticket}
      A:
      """,
      max_tokens=1024, #seting the maximum number of tokens the model should generate for this task.
      stop=["Q:", "\n"],
      temperature=0.01, #setting the value for temperature.
      echo=False,
    )

    temp_output = model_output["choices"][0]["text"]
    final_output = temp_output[temp_output.index('{'):]

    return final_output

# %%
prompt_1 = """
You're purpose is to classify the give text and provide a general label based on the query from the customer

You will be given a customer feedback of our product try to understand what difficulty the customer has faced and summarize it to one just word

The response should be in the form of JSON format for example
{"Category":"classified_label"}

Ensure that the curly braces are closed properly and there are no additional characters in the output
"""

# %%
start = time.time()
data_1['model_response'] = data_1['support_ticket_text'].apply(lambda x: response_1(prompt_1, x))
end = time.time()
# Out:
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     6.71 ms /     7 runs   (    0.96 ms per token,  1042.60 tokens per second)
# llama_print_timings: prompt eval time =  2060.10 ms /   164 tokens (   12.56 ms per token,    79.61 tokens per second)
# llama_print_timings:        eval time =  2579.97 ms /     6 runs   (  429.99 ms per token,     2.33 tokens per second)
# llama_print_timings:       total time =  4671.66 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     8.60 ms /     9 runs   (    0.96 ms per token,  1046.88 tokens per second)
# llama_print_timings: prompt eval time =  1604.75 ms /    51 tokens (   31.47 ms per token,    31.78 tokens per second)
# llama_print_timings:        eval time =  3424.49 ms /     8 runs   (  428.06 ms per token,     2.34 tokens per second)
# llama_print_timings:       total time =  5069.76 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     7.17 ms /     7 runs   (    1.02 ms per token,   976.70 tokens per second)
# llama_print_timings: prompt eval time =  1574.41 ms /    47 tokens (   33.50 ms per token,    29.85 tokens per second)
# llama_print_timings:        eval time =  2560.46 ms /     6 runs   (  426.74 ms per token,     2.34 tokens per second)
# llama_print_timings:       total time =  4167.44 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     9.68 ms /    10 runs   (    0.97 ms per token,  1033.27 tokens per second)
# llama_print_timings: prompt eval time =  1608.89 ms /    58 tokens (   27.74 ms per token,    36.05 tokens per second)
# llama_print_timings:        eval time =  3887.89 ms /     9 runs   (  431.99 ms per token,     2.31 tokens per second)
# llama_print_timings:       total time =  5543.13 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     6.77 ms /     7 runs   (    0.97 ms per token,  1034.13 tokens per second)
# llama_print_timings: prompt eval time =  1552.53 ms /    32 tokens (   48.52 ms per token,    20.61 tokens per second)
# llama_print_timings:        eval time =  2588.99 ms /     6 runs   (  431.50 ms per token,     2.32 tokens per second)
# llama_print_timings:       total time =  4173.77 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     7.82 ms /     8 runs   (    0.98 ms per token,  1023.54 tokens per second)
# llama_print_timings: prompt eval time =  9823.20 ms /    30 tokens (  327.44 ms per token,     3.05 tokens per second)
# llama_print_timings:        eval time =  3061.40 ms /     7 runs   (  437.34 ms per token,     2.29 tokens per second)
# llama_print_timings:       total time = 12921.66 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     7.00 ms /     7 runs   (    1.00 ms per token,  1000.57 tokens per second)
# llama_print_timings: prompt eval time =  1549.70 ms /    33 tokens (   46.96 ms per token,    21.29 tokens per second)
# llama_print_timings:        eval time =  2571.85 ms /     6 runs   (  428.64 ms per token,     2.33 tokens per second)
# llama_print_timings:       total time =  4153.26 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     9.52 ms /    10 runs   (    0.95 ms per token,  1050.20 tokens per second)
# llama_print_timings: prompt eval time =  1559.05 ms /    35 tokens (   44.54 ms per token,    22.45 tokens per second)
# llama_print_timings:        eval time =  3890.76 ms /     9 runs   (  432.31 ms per token,     2.31 tokens per second)
# llama_print_timings:       total time =  5494.20 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     7.07 ms /     7 runs   (    1.01 ms per token,   989.68 tokens per second)
# llama_print_timings: prompt eval time =  9239.68 ms /    30 tokens (  307.99 ms per token,     3.25 tokens per second)
# llama_print_timings:        eval time =  2588.70 ms /     6 runs   (  431.45 ms per token,     2.32 tokens per second)
# llama_print_timings:       total time = 11861.06 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     7.56 ms /     7 runs   (    1.08 ms per token,   925.68 tokens per second)
# llama_print_timings: prompt eval time =  1545.89 ms /    37 tokens (   41.78 ms per token,    23.93 tokens per second)
# llama_print_timings:        eval time =  2993.97 ms /     6 runs   (  499.00 ms per token,     2.00 tokens per second)
# llama_print_timings:       total time =  4574.49 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     7.65 ms /     8 runs   (    0.96 ms per token,  1045.89 tokens per second)
# llama_print_timings: prompt eval time =  1543.83 ms /    32 tokens (   48.24 ms per token,    20.73 tokens per second)
# llama_print_timings:        eval time =  3043.38 ms /     7 runs   (  434.77 ms per token,     2.30 tokens per second)
# llama_print_timings:       total time =  4623.42 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    15.76 ms /    16 runs   (    0.98 ms per token,  1015.23 tokens per second)
# llama_print_timings: prompt eval time =  1546.22 ms /    36 tokens (   42.95 ms per token,    23.28 tokens per second)
# llama_print_timings:        eval time =  6513.51 ms /    15 runs   (  434.23 ms per token,     2.30 tokens per second)
# llama_print_timings:       total time =  8133.29 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     6.93 ms /     7 runs   (    0.99 ms per token,  1009.81 tokens per second)
# llama_print_timings: prompt eval time =  1554.74 ms /    35 tokens (   44.42 ms per token,    22.51 tokens per second)
# llama_print_timings:        eval time =  2578.93 ms /     6 runs   (  429.82 ms per token,     2.33 tokens per second)
# llama_print_timings:       total time =  4165.89 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     8.00 ms /     8 runs   (    1.00 ms per token,   999.75 tokens per second)
# llama_print_timings: prompt eval time =  8010.96 ms /    26 tokens (  308.11 ms per token,     3.25 tokens per second)
# llama_print_timings:        eval time =  3000.23 ms /     7 runs   (  428.60 ms per token,     2.33 tokens per second)
# llama_print_timings:       total time = 11048.43 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     7.23 ms /     7 runs   (    1.03 ms per token,   968.05 tokens per second)
# llama_print_timings: prompt eval time =  1597.86 ms /    33 tokens (   48.42 ms per token,    20.65 tokens per second)
# llama_print_timings:        eval time =  2842.56 ms /     6 runs   (  473.76 ms per token,     2.11 tokens per second)
# llama_print_timings:       total time =  4473.56 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     6.74 ms /     7 runs   (    0.96 ms per token,  1038.27 tokens per second)
# llama_print_timings: prompt eval time =  6738.25 ms /    22 tokens (  306.28 ms per token,     3.26 tokens per second)
# llama_print_timings:        eval time =  2569.88 ms /     6 runs   (  428.31 ms per token,     2.33 tokens per second)
# llama_print_timings:       total time =  9340.12 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     6.71 ms /     7 runs   (    0.96 ms per token,  1043.69 tokens per second)
# llama_print_timings: prompt eval time =  8528.15 ms /    28 tokens (  304.58 ms per token,     3.28 tokens per second)
# llama_print_timings:        eval time =  2594.63 ms /     6 runs   (  432.44 ms per token,     2.31 tokens per second)
# llama_print_timings:       total time = 11155.58 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     8.89 ms /     8 runs   (    1.11 ms per token,   899.69 tokens per second)
# llama_print_timings: prompt eval time =  7184.26 ms /    23 tokens (  312.36 ms per token,     3.20 tokens per second)
# llama_print_timings:        eval time =  3447.56 ms /     7 runs   (  492.51 ms per token,     2.03 tokens per second)
# llama_print_timings:       total time = 10671.64 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     6.70 ms /     7 runs   (    0.96 ms per token,  1045.56 tokens per second)
# llama_print_timings: prompt eval time =  7732.83 ms /    25 tokens (  309.31 ms per token,     3.23 tokens per second)
# llama_print_timings:        eval time =  2617.47 ms /     6 runs   (  436.24 ms per token,     2.29 tokens per second)
# llama_print_timings:       total time = 10381.82 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     9.81 ms /    10 runs   (    0.98 ms per token,  1019.78 tokens per second)
# llama_print_timings: prompt eval time =  2086.43 ms /   175 tokens (   11.92 ms per token,    83.88 tokens per second)
# llama_print_timings:        eval time =  3904.46 ms /     9 runs   (  433.83 ms per token,     2.31 tokens per second)
# llama_print_timings:       total time =  6037.32 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =     9.69 ms /    10 runs   (    0.97 ms per token,  1031.78 tokens per second)
# llama_print_timings: prompt eval time =  2660.67 ms /   289 tokens (    9.21 ms per token,   108.62 tokens per second)
# llama_print_timings:        eval time =  3975.88 ms /     9 runs   (  441.76 ms per token,     2.26 tokens per second)
# llama_print_timings:       total time =  6683.11 ms

# %%
print("Time taken ",(end-start))
# Out:
# Time taken  149.3834719657898

# %%
data_1.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                   model_response
# 0        {"Category":"Internet"}
# 1  {"Category":"Hardware_issue"}
# 2       {"Category":"Data Loss"}
# 3     {"Category":"WiFi_Signal"}
# 4         {"Category":"Battery"}

# %%
i = 2
print(data_1.loc[i, 'support_ticket_text'])
# Out:
# I've accidentally deleted essential work documents, causing substantial data loss. I understand the need to avoid further actions on my device. Can you please prioritize the data recovery process and guide me through it?

# %%
print(data_1.loc[i, 'model_response'])
# Out:
# {"Category":"Data Loss"}

# %%
# applying the function to the model response
data_1['model_response_parsed'] = data_1['model_response'].apply(extract_json_data)
data_1['model_response_parsed'].head()
# Out:
# 0          {'Category': 'Internet'}
# 1    {'Category': 'Hardware_issue'}
# 2         {'Category': 'Data Loss'}
# 3       {'Category': 'WiFi_Signal'}
# 4           {'Category': 'Battery'}
# Name: model_response_parsed, dtype: object

# %%
data_1['model_response_parsed'].value_counts()
# Out:
# {'Category': 'Hardware'}                                     5
# {'Category': 'Data Recovery'}                                3
# {'Category': 'Connectivity'}                                 2
# {'Category': 'Data Loss'}                                    1
# {'Category': 'Internet'}                                     1
# {'Category': 'Hardware_issue'}                               1
# {'Category': 'Account_Access'}                               1
# {'Category': 'Battery'}                                      1
# {'Category': 'WiFi_Signal'}                                  1
# {'Category': 'Technical_Support'}                            1
# {'Category': 'Performance'}                                  1
# {'Category': 'Technical_Issue', 'SubCategory': 'Display'}    1
# {'Category': 'Internet_Issue'}                               1
# {'Category': 'Software_Issue'}                               1
# Name: model_response_parsed, dtype: int64

# %%
# Normalizing the model_response_parsed column
model_response_parsed_df_1 = pd.json_normalize(data_1['model_response_parsed'])
model_response_parsed_df_1.head()
# Out:
#          Category SubCategory
# 0        Internet         NaN
# 1  Hardware_issue         NaN
# 2       Data Loss         NaN
# 3     WiFi_Signal         NaN
# 4         Battery         NaN

# %%
# Concatinating two dataframes
data_with_parsed_model_output_1 = pd.concat([data_1, model_response_parsed_df_1], axis=1)
data_with_parsed_model_output_1.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                   model_response           model_response_parsed  \
# 0        {"Category":"Internet"}        {'Category': 'Internet'}
# 1  {"Category":"Hardware_issue"}  {'Category': 'Hardware_issue'}
# 2       {"Category":"Data Loss"}       {'Category': 'Data Loss'}
# 3     {"Category":"WiFi_Signal"}     {'Category': 'WiFi_Signal'}
# 4         {"Category":"Battery"}         {'Category': 'Battery'}
#
#          Category SubCategory
# 0        Internet         NaN
# 1  Hardware_issue         NaN
# 2       Data Loss         NaN
# 3     WiFi_Signal         NaN
# 4         Battery         NaN

# %%
# Dropping model_response and model_response_parsed columns
final_data_1 = data_with_parsed_model_output_1.drop(['model_response','model_response_parsed','SubCategory'], axis=1)
final_data_1.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#          Category
# 0        Internet
# 1  Hardware_issue
# 2       Data Loss
# 3     WiFi_Signal
# 4         Battery

# %% [markdown]
# ## **Task 2: Creating Tags**

# %%
data_2 = data.copy()

# %%
def response_2(prompt,ticket,category):
    model_output = llm(
      f"""
      Q: {prompt}
      Support ticket: {ticket}
      Category: {category}
      A:
      """,
      max_tokens=1024, # setting the maximum number of tokens the model should generate for this task.
      stop=["Q:", "\n"],
      temperature=0.01, # setting the value for temperature.
      echo=False,
    )

    temp_output = model_output["choices"][0]["text"]
    final_output = temp_output[temp_output.index('{'):]

    return final_output

# %%
prompt_2 = """
You're purpose is to classify the tags based on the support ticket and their respective categories the tagging is for the IT department 
you will be given support tickets and their category understand the most relevant words from both of them and create appropriate tags 

Make sure that you generate tags to each and every support ticket it is very important to generate tags for every support ticket and category
also the output tags that you provide should be in JSON format for example

{"Tags" : ["WiFi", "data_loss", "connection_issue"]} (Note these are just Example Tags, you should determine what the tags are relevant to the tickets)
Also make sure that all the curly brackes are properly closed and there are no additional characters from the output 
"""

# %%
start = time.time()
data_2["model_response"]=final_data_1[['support_ticket_text','Category']].apply(lambda x: response_2(prompt_2, x[0],x[1]),axis =1)
end = time.time()
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    21.46 ms /    22 runs   (    0.98 ms per token,  1025.21 tokens per second)
# llama_print_timings: prompt eval time =  2253.30 ms /   218 tokens (   10.34 ms per token,    96.75 tokens per second)
# llama_print_timings:        eval time =  9148.42 ms /    21 runs   (  435.64 ms per token,     2.30 tokens per second)
# llama_print_timings:       total time = 11504.05 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    18.55 ms /    19 runs   (    0.98 ms per token,  1024.31 tokens per second)
# llama_print_timings: prompt eval time =  1623.71 ms /    59 tokens (   27.52 ms per token,    36.34 tokens per second)
# llama_print_timings:        eval time =  7837.63 ms /    18 runs   (  435.42 ms per token,     2.30 tokens per second)
# llama_print_timings:       total time =  9548.40 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    13.10 ms /    11 runs   (    1.19 ms per token,   839.44 tokens per second)
# llama_print_timings: prompt eval time =  1595.91 ms /    53 tokens (   30.11 ms per token,    33.21 tokens per second)
# llama_print_timings:        eval time =  4691.35 ms /    10 runs   (  469.14 ms per token,     2.13 tokens per second)
# llama_print_timings:       total time =  6344.79 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    15.74 ms /    16 runs   (    0.98 ms per token,  1016.45 tokens per second)
# llama_print_timings: prompt eval time =  1712.82 ms /    66 tokens (   25.95 ms per token,    38.53 tokens per second)
# llama_print_timings:        eval time =  6573.13 ms /    15 runs   (  438.21 ms per token,     2.28 tokens per second)
# llama_print_timings:       total time =  8359.62 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    17.68 ms /    17 runs   (    1.04 ms per token,   961.81 tokens per second)
# llama_print_timings: prompt eval time =  1580.62 ms /    38 tokens (   41.60 ms per token,    24.04 tokens per second)
# llama_print_timings:        eval time =  6968.06 ms /    16 runs   (  435.50 ms per token,     2.30 tokens per second)
# llama_print_timings:       total time =  8629.20 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    15.35 ms /    16 runs   (    0.96 ms per token,  1042.14 tokens per second)
# llama_print_timings: prompt eval time =  1579.55 ms /    37 tokens (   42.69 ms per token,    23.42 tokens per second)
# llama_print_timings:        eval time =  6554.85 ms /    15 runs   (  436.99 ms per token,     2.29 tokens per second)
# llama_print_timings:       total time =  8208.64 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    19.21 ms /    16 runs   (    1.20 ms per token,   832.81 tokens per second)
# llama_print_timings: prompt eval time =  1572.08 ms /    38 tokens (   41.37 ms per token,    24.17 tokens per second)
# llama_print_timings:        eval time =  6914.03 ms /    15 runs   (  460.94 ms per token,     2.17 tokens per second)
# llama_print_timings:       total time =  8572.02 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.43 ms /    17 runs   (    0.97 ms per token,  1034.88 tokens per second)
# llama_print_timings: prompt eval time =  1575.12 ms /    42 tokens (   37.50 ms per token,    26.66 tokens per second)
# llama_print_timings:        eval time =  6929.53 ms /    16 runs   (  433.10 ms per token,     2.31 tokens per second)
# llama_print_timings:       total time =  8582.90 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.60 ms /    17 runs   (    0.98 ms per token,  1023.85 tokens per second)
# llama_print_timings: prompt eval time =  1583.83 ms /    36 tokens (   44.00 ms per token,    22.73 tokens per second)
# llama_print_timings:        eval time =  6971.10 ms /    16 runs   (  435.69 ms per token,     2.30 tokens per second)
# llama_print_timings:       total time =  8634.33 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    24.73 ms /    25 runs   (    0.99 ms per token,  1011.08 tokens per second)
# llama_print_timings: prompt eval time =  1580.75 ms /    43 tokens (   36.76 ms per token,    27.20 tokens per second)
# llama_print_timings:        eval time = 10863.95 ms /    24 runs   (  452.66 ms per token,     2.21 tokens per second)
# llama_print_timings:       total time = 12561.90 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    14.81 ms /    15 runs   (    0.99 ms per token,  1012.69 tokens per second)
# llama_print_timings: prompt eval time =  1575.82 ms /    39 tokens (   40.41 ms per token,    24.75 tokens per second)
# llama_print_timings:        eval time =  6078.86 ms /    14 runs   (  434.20 ms per token,     2.30 tokens per second)
# llama_print_timings:       total time =  7723.78 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    19.55 ms /    19 runs   (    1.03 ms per token,   971.97 tokens per second)
# llama_print_timings: prompt eval time =  1582.80 ms /    44 tokens (   35.97 ms per token,    27.80 tokens per second)
# llama_print_timings:        eval time =  7950.65 ms /    18 runs   (  441.70 ms per token,     2.26 tokens per second)
# llama_print_timings:       total time =  9625.82 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    20.47 ms /    21 runs   (    0.97 ms per token,  1025.94 tokens per second)
# llama_print_timings: prompt eval time =  1565.96 ms /    41 tokens (   38.19 ms per token,    26.18 tokens per second)
# llama_print_timings:        eval time =  8758.45 ms /    20 runs   (  437.92 ms per token,     2.28 tokens per second)
# llama_print_timings:       total time = 10423.33 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    20.12 ms /    17 runs   (    1.18 ms per token,   845.10 tokens per second)
# llama_print_timings: prompt eval time =  1598.73 ms /    33 tokens (   48.45 ms per token,    20.64 tokens per second)
# llama_print_timings:        eval time =  7284.09 ms /    16 runs   (  455.26 ms per token,     2.20 tokens per second)
# llama_print_timings:       total time =  8972.64 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    15.72 ms /    16 runs   (    0.98 ms per token,  1017.55 tokens per second)
# llama_print_timings: prompt eval time =  1569.53 ms /    39 tokens (   40.24 ms per token,    24.85 tokens per second)
# llama_print_timings:        eval time =  6586.16 ms /    15 runs   (  439.08 ms per token,     2.28 tokens per second)
# llama_print_timings:       total time =  8230.38 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    19.45 ms /    19 runs   (    1.02 ms per token,   976.91 tokens per second)
# llama_print_timings: prompt eval time =  8812.14 ms /    28 tokens (  314.72 ms per token,     3.18 tokens per second)
# llama_print_timings:        eval time =  8122.66 ms /    18 runs   (  451.26 ms per token,     2.22 tokens per second)
# llama_print_timings:       total time = 17028.52 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    15.21 ms /    16 runs   (    0.95 ms per token,  1052.29 tokens per second)
# llama_print_timings: prompt eval time =  1643.37 ms /    34 tokens (   48.33 ms per token,    20.69 tokens per second)
# llama_print_timings:        eval time =  6602.70 ms /    15 runs   (  440.18 ms per token,     2.27 tokens per second)
# llama_print_timings:       total time =  8319.20 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    17.01 ms /    17 runs   (    1.00 ms per token,   999.24 tokens per second)
# llama_print_timings: prompt eval time =  9545.37 ms /    30 tokens (  318.18 ms per token,     3.14 tokens per second)
# llama_print_timings:        eval time =  7053.73 ms /    16 runs   (  440.86 ms per token,     2.27 tokens per second)
# llama_print_timings:       total time = 16679.72 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.20 ms /    17 runs   (    0.95 ms per token,  1049.32 tokens per second)
# llama_print_timings: prompt eval time = 10212.49 ms /    31 tokens (  329.44 ms per token,     3.04 tokens per second)
# llama_print_timings:        eval time =  6991.49 ms /    16 runs   (  436.97 ms per token,     2.29 tokens per second)
# llama_print_timings:       total time = 17282.43 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    23.52 ms /    24 runs   (    0.98 ms per token,  1020.41 tokens per second)
# llama_print_timings: prompt eval time =  2192.11 ms /   183 tokens (   11.98 ms per token,    83.48 tokens per second)
# llama_print_timings:        eval time = 10102.65 ms /    23 runs   (  439.25 ms per token,     2.28 tokens per second)
# llama_print_timings:       total time = 12408.47 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    30.31 ms /    31 runs   (    0.98 ms per token,  1022.70 tokens per second)
# llama_print_timings: prompt eval time =  2789.67 ms /   297 tokens (    9.39 ms per token,   106.46 tokens per second)
# llama_print_timings:        eval time = 13697.41 ms /    30 runs   (  456.58 ms per token,     2.19 tokens per second)
# llama_print_timings:       total time = 16636.67 ms

# %%
print("Time taken ",end-start)
# Out:
# Time taken  224.32707834243774

# %%
data_2.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       model_response
# 0  {"Tags" : ["connection_issue", "internet", "sl...
# 1       {"Tags" : ["Hardware", "laptop", "startup"]}
# 2                           {"Tags" : ["data_loss"]}
# 3                 {"Tags" : ["WiFi", "weak_signal"]}
# 4         {"Tags" : ["smartphone", "battery_drain"]}

# %%
i = 2
print(data_2.loc[i, 'support_ticket_text'])
# Out:
# I've accidentally deleted essential work documents, causing substantial data loss. I understand the need to avoid further actions on my device. Can you please prioritize the data recovery process and guide me through it?

# %%
print(data_2.loc[i, 'model_response'])
# Out:
# {"Tags" : ["data_loss"]}

# %%
# Applying the function to the model response
data_2['model_response_parsed'] = data_2['model_response'].apply(extract_json_data)

# %%
data_2["model_response_parsed"]
# Out:
# 0     {'Tags': ['connection_issue', 'internet', 'slo...
# 1           {'Tags': ['Hardware', 'laptop', 'startup']}
# 2                               {'Tags': ['data_loss']}
# 3                     {'Tags': ['WiFi', 'weak_signal']}
# 4             {'Tags': ['smartphone', 'battery_drain']}
# 5        {'Tags': ['Account_Access', 'Password_Reset']}
# 6       {'Tags': ['performance_issue', 'productivity']}
# 7            {'Tags': ['BlueScreen', 'Hardware_Issue']}
# 8             {'Tags': ['Hard_drive', 'Data_recovery']}
# 9     {'Tags': ['Graphics_card', 'gaming_laptop', 'h...
# 10                  {'Tags': ['data_loss', 'recovery']}
# 11        {'Tags': ['Screen_issue', 'Technical_Issue']}
# 12     {'Tags': ['laptop', 'water_damage', 'hardware']}
# 13           {'Tags': ['data_recovery', 'flash_drive']}
# 14             {'Tags': ['touchpad', 'hardware_issue']}
# 15    {'Tags': ['connection_issue', 'internet', 'dro...
# 16               {'Tags': ['WiFi', 'connection_issue']}
# 17             {'Tags': ['data_loss', 'file_recovery']}
# 18            {'Tags': ['Hard_drive', 'Data_recovery']}
# 19    {'Tags': ['Internet_issue', 'connection_issue'...
# 20    {'Tags': ['software_issue', 'application_freez...
# Name: model_response_parsed, dtype: object

# %%
# Normalizing the model_response_parsed column
model_response_parsed_df_2 = pd.json_normalize(data_2['model_response_parsed'])
model_response_parsed_df_2.head()
# Out:
#                                               Tags
# 0  [connection_issue, internet, slow_connectivity]
# 1                      [Hardware, laptop, startup]
# 2                                      [data_loss]
# 3                              [WiFi, weak_signal]
# 4                      [smartphone, battery_drain]

# %%
# Concatinating two dataframes
data_with_parsed_model_output_2 = pd.concat([data_2, model_response_parsed_df_2], axis=1)
data_with_parsed_model_output_2.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       model_response  \
# 0  {"Tags" : ["connection_issue", "internet", "sl...
# 1       {"Tags" : ["Hardware", "laptop", "startup"]}
# 2                           {"Tags" : ["data_loss"]}
# 3                 {"Tags" : ["WiFi", "weak_signal"]}
# 4         {"Tags" : ["smartphone", "battery_drain"]}
#
#                                model_response_parsed  \
# 0  {'Tags': ['connection_issue', 'internet', 'slo...
# 1        {'Tags': ['Hardware', 'laptop', 'startup']}
# 2                            {'Tags': ['data_loss']}
# 3                  {'Tags': ['WiFi', 'weak_signal']}
# 4          {'Tags': ['smartphone', 'battery_drain']}
#
#                                               Tags
# 0  [connection_issue, internet, slow_connectivity]
# 1                      [Hardware, laptop, startup]
# 2                                      [data_loss]
# 3                              [WiFi, weak_signal]
# 4                      [smartphone, battery_drain]

# %%
# Dropping model_response and model_response_parsed columns
final_data_2 = data_with_parsed_model_output_2.drop(['model_response','model_response_parsed'], axis=1)
final_data_2.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                               Tags
# 0  [connection_issue, internet, slow_connectivity]
# 1                      [Hardware, laptop, startup]
# 2                                      [data_loss]
# 3                              [WiFi, weak_signal]
# 4                      [smartphone, battery_drain]

# %%
# Checking the value counts of Category column
final_data_2['Tags'].value_counts()
# Out:
# [Hard_drive, Data_recovery]                                             2
# [connection_issue, internet, slow_connectivity]                         1
# [data_loss]                                                             1
# [Hardware, laptop, startup]                                             1
# [WiFi, weak_signal]                                                     1
# [smartphone, battery_drain]                                             1
# [performance_issue, productivity]                                       1
# [Account_Access, Password_Reset]                                        1
# [BlueScreen, Hardware_Issue]                                            1
# [Graphics_card, gaming_laptop, hardware_issue]                          1
# [data_loss, recovery]                                                   1
# [Screen_issue, Technical_Issue]                                         1
# [laptop, water_damage, hardware]                                        1
# [data_recovery, flash_drive]                                            1
# [touchpad, hardware_issue]                                              1
# [connection_issue, internet, dropping]                                  1
# [WiFi, connection_issue]                                                1
# [data_loss, file_recovery]                                              1
# [Internet_issue, connection_issue, slow_internet]                       1
# [software_issue, application_freeze, unexplained_crashes, data_loss]    1
# Name: Tags, dtype: int64

# %%
final_data_2 = pd.concat([final_data_2,final_data_1["Category"]],axis=1)

# %%
final_data_2 = final_data_2[["support_tick_id","support_ticket_text","Category","Tags"]]
final_data_2
# Out:
#    support_tick_id                                support_ticket_text  \
# 0       ST2023-006  My internet connection has significantly slowe...
# 1       ST2023-007  Urgent help required! My laptop refuses to sta...
# 2       ST2023-008  I've accidentally deleted essential work docum...
# 3       ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4       ST2023-010  My smartphone battery is draining rapidly, eve...
# 5       ST2023-011  I'm locked out of my online banking account an...
# 6       ST2023-012  My computer's performance is sluggish, severel...
# 7       ST2023-013  I'm experiencing a recurring blue screen error...
# 8       ST2023-014  My external hard drive isn't being recognized ...
# 9       ST2023-015  The graphics card in my gaming laptop seems to...
# 10      ST2023-016  I accidentally formatted my USB drive with cri...
# 11      ST2023-017  My computer's screen has gone black, and I can...
# 12      ST2023-018  I accidentally spilled water on my laptop, and...
# 13      ST2023-019  My USB flash drive is physically damaged, and ...
# 14      ST2023-020  The touchpad on my laptop has stopped working,...
# 15      ST2023-021  My internet connection is frequently dropping,...
# 16      ST2023-022  Wi-Fi is inconsistent despite proximity to the...
# 17      ST2023-023  I accidentally formatted my USB drive with cru...
# 18      ST2023-024  My external hard drive isn't being recognized,...
# 19      ST2023-025  I am experiencing a critical problem with my i...
# 20      ST2023-026  I hope this message finds you well. I am writi...
#
#              Category                                               Tags
# 0            Internet    [connection_issue, internet, slow_connectivity]
# 1      Hardware_issue                        [Hardware, laptop, startup]
# 2           Data Loss                                        [data_loss]
# 3         WiFi_Signal                                [WiFi, weak_signal]
# 4             Battery                        [smartphone, battery_drain]
# 5      Account_Access                   [Account_Access, Password_Reset]
# 6         Performance                  [performance_issue, productivity]
# 7   Technical_Support                       [BlueScreen, Hardware_Issue]
# 8            Hardware                        [Hard_drive, Data_recovery]
# 9            Hardware     [Graphics_card, gaming_laptop, hardware_issue]
# 10      Data Recovery                              [data_loss, recovery]
# 11    Technical_Issue                    [Screen_issue, Technical_Issue]
# 12           Hardware                   [laptop, water_damage, hardware]
# 13      Data Recovery                       [data_recovery, flash_drive]
# 14           Hardware                         [touchpad, hardware_issue]
# 15       Connectivity             [connection_issue, internet, dropping]
# 16       Connectivity                           [WiFi, connection_issue]
# 17      Data Recovery                         [data_loss, file_recovery]
# 18           Hardware                        [Hard_drive, Data_recovery]
# 19     Internet_Issue  [Internet_issue, connection_issue, slow_internet]
# 20     Software_Issue  [software_issue, application_freeze, unexplain...

# %% [markdown]
# ## **Task 3: Assigning Priority and ETA**

# %%
data_3 = data.copy()

# %%
def response_3(prompt,ticket,category,tags):
    model_output = llm(
      f"""
      Q: {prompt}
      Support ticket: {ticket}
      Category: {category}
      Tags: {tags}
      A:
      """,
      max_tokens=1024,  # setting the maximum number of tokens the model should generate for this task.
      stop=["Q:", "\n"],
      temperature=0.01, # setting the value for temperature.
      echo=False,
    )

    temp_output = model_output["choices"][0]["text"]
    final_output = temp_output[temp_output.index('{'):]

    return final_output

# %%
prompt_3 = """
   You're task it to classify the Priority and ETA for the support tickets based on the severity of the issue and the time that it would take to fix the .
   You'll be given support ticket their category and tags understand the severity of the issue and assign the Priority and ETA.
   
   The output should be in JSON Format for example
   {"Priority" : "High", "ETA" : "Immediate"}
   {"Priority" : "Medium", "ETA" : "2 Days"}
   {"Priority" : "Low", "ETA" : "2 - 3 Business Days"}
   (Note: this is just an example you've to understand the support ticket its category and tags, based on it you should assign Priority and ETA to it).
   
   Make sure that Priority and ETA is generated for each support ticket its important that none gets missed out.
   Also make sure that all the curly braces are closed and there are no additional characters in the output.
"""

# %%
# Applying generate_llama_response function on support_ticket_text column
start = time.time()
data_3['model_response'] = final_data_2[['support_ticket_text','Category','Tags']].apply(lambda x: response_3(prompt_3, x[0],x[1],x[2]),axis=1)
end = time.time()
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.49 ms /    17 runs   (    0.97 ms per token,  1031.05 tokens per second)
# llama_print_timings: prompt eval time =  2660.39 ms /   311 tokens (    8.55 ms per token,   116.90 tokens per second)
# llama_print_timings:        eval time =  6979.88 ms /    16 runs   (  436.24 ms per token,     2.29 tokens per second)
# llama_print_timings:       total time =  9719.73 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.58 ms /    17 runs   (    0.98 ms per token,  1025.52 tokens per second)
# llama_print_timings: prompt eval time =  1784.24 ms /    77 tokens (   23.17 ms per token,    43.16 tokens per second)
# llama_print_timings:        eval time =  7346.11 ms /    16 runs   (  459.13 ms per token,     2.18 tokens per second)
# llama_print_timings:       total time =  9209.56 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.59 ms /    17 runs   (    0.98 ms per token,  1024.65 tokens per second)
# llama_print_timings: prompt eval time =  1649.31 ms /    63 tokens (   26.18 ms per token,    38.20 tokens per second)
# llama_print_timings:        eval time =  7084.85 ms /    16 runs   (  442.80 ms per token,     2.26 tokens per second)
# llama_print_timings:       total time =  8814.25 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    17.76 ms /    18 runs   (    0.99 ms per token,  1013.29 tokens per second)
# llama_print_timings: prompt eval time =  1806.01 ms /    81 tokens (   22.30 ms per token,    44.85 tokens per second)
# llama_print_timings:        eval time =  7648.18 ms /    17 runs   (  449.89 ms per token,     2.22 tokens per second)
# llama_print_timings:       total time =  9541.11 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    22.57 ms /    22 runs   (    1.03 ms per token,   974.57 tokens per second)
# llama_print_timings: prompt eval time =  1628.05 ms /    54 tokens (   30.15 ms per token,    33.17 tokens per second)
# llama_print_timings:        eval time =  9669.63 ms /    21 runs   (  460.46 ms per token,     2.17 tokens per second)
# llama_print_timings:       total time = 11404.28 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.54 ms /    17 runs   (    0.97 ms per token,  1027.62 tokens per second)
# llama_print_timings: prompt eval time =  1606.02 ms /    52 tokens (   30.89 ms per token,    32.38 tokens per second)
# llama_print_timings:        eval time =  7027.66 ms /    16 runs   (  439.23 ms per token,     2.28 tokens per second)
# llama_print_timings:       total time =  8712.94 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.90 ms /    17 runs   (    0.99 ms per token,  1005.98 tokens per second)
# llama_print_timings: prompt eval time =  1604.75 ms /    53 tokens (   30.28 ms per token,    33.03 tokens per second)
# llama_print_timings:        eval time =  7144.25 ms /    16 runs   (  446.52 ms per token,     2.24 tokens per second)
# llama_print_timings:       total time =  8829.32 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.73 ms /    17 runs   (    0.98 ms per token,  1016.38 tokens per second)
# llama_print_timings: prompt eval time =  1625.49 ms /    58 tokens (   28.03 ms per token,    35.68 tokens per second)
# llama_print_timings:        eval time =  7091.90 ms /    16 runs   (  443.24 ms per token,     2.26 tokens per second)
# llama_print_timings:       total time =  8797.66 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.51 ms /    17 runs   (    0.97 ms per token,  1029.55 tokens per second)
# llama_print_timings: prompt eval time =  1719.18 ms /    52 tokens (   33.06 ms per token,    30.25 tokens per second)
# llama_print_timings:        eval time =  7274.32 ms /    16 runs   (  454.65 ms per token,     2.20 tokens per second)
# llama_print_timings:       total time =  9073.72 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    17.00 ms /    17 runs   (    1.00 ms per token,  1000.24 tokens per second)
# llama_print_timings: prompt eval time =  1738.67 ms /    67 tokens (   25.95 ms per token,    38.54 tokens per second)
# llama_print_timings:        eval time =  7183.91 ms /    16 runs   (  448.99 ms per token,     2.23 tokens per second)
# llama_print_timings:       total time =  9003.56 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.43 ms /    17 runs   (    0.97 ms per token,  1034.94 tokens per second)
# llama_print_timings: prompt eval time =  1611.87 ms /    53 tokens (   30.41 ms per token,    32.88 tokens per second)
# llama_print_timings:        eval time =  7149.95 ms /    16 runs   (  446.87 ms per token,     2.24 tokens per second)
# llama_print_timings:       total time =  8842.38 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    18.01 ms /    17 runs   (    1.06 ms per token,   943.76 tokens per second)
# llama_print_timings: prompt eval time =  1662.20 ms /    62 tokens (   26.81 ms per token,    37.30 tokens per second)
# llama_print_timings:        eval time =  7733.93 ms /    16 runs   (  483.37 ms per token,     2.07 tokens per second)
# llama_print_timings:       total time =  9482.32 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.79 ms /    17 runs   (    0.99 ms per token,  1012.63 tokens per second)
# llama_print_timings: prompt eval time =  1651.60 ms /    61 tokens (   27.08 ms per token,    36.93 tokens per second)
# llama_print_timings:        eval time =  7128.93 ms /    16 runs   (  445.56 ms per token,     2.24 tokens per second)
# llama_print_timings:       total time =  8861.42 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.75 ms /    17 runs   (    0.99 ms per token,  1014.74 tokens per second)
# llama_print_timings: prompt eval time =  1623.31 ms /    49 tokens (   33.13 ms per token,    30.19 tokens per second)
# llama_print_timings:        eval time =  7061.00 ms /    16 runs   (  441.31 ms per token,     2.27 tokens per second)
# llama_print_timings:       total time =  8763.59 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.27 ms /    17 runs   (    0.96 ms per token,  1044.80 tokens per second)
# llama_print_timings: prompt eval time =  1618.08 ms /    54 tokens (   29.96 ms per token,    33.37 tokens per second)
# llama_print_timings:        eval time =  7014.72 ms /    16 runs   (  438.42 ms per token,     2.28 tokens per second)
# llama_print_timings:       total time =  8711.24 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    17.31 ms /    17 runs   (    1.02 ms per token,   982.15 tokens per second)
# llama_print_timings: prompt eval time =  1598.84 ms /    46 tokens (   34.76 ms per token,    28.77 tokens per second)
# llama_print_timings:        eval time =  7395.12 ms /    16 runs   (  462.20 ms per token,     2.16 tokens per second)
# llama_print_timings:       total time =  9076.34 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.84 ms /    17 runs   (    0.99 ms per token,  1009.68 tokens per second)
# llama_print_timings: prompt eval time =  1592.83 ms /    49 tokens (   32.51 ms per token,    30.76 tokens per second)
# llama_print_timings:        eval time =  7048.88 ms /    16 runs   (  440.56 ms per token,     2.27 tokens per second)
# llama_print_timings:       total time =  8722.90 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.47 ms /    17 runs   (    0.97 ms per token,  1031.99 tokens per second)
# llama_print_timings: prompt eval time =  1603.80 ms /    46 tokens (   34.87 ms per token,    28.68 tokens per second)
# llama_print_timings:        eval time =  7108.73 ms /    16 runs   (  444.30 ms per token,     2.25 tokens per second)
# llama_print_timings:       total time =  8792.20 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    18.25 ms /    17 runs   (    1.07 ms per token,   931.30 tokens per second)
# llama_print_timings: prompt eval time =  1584.22 ms /    47 tokens (   33.71 ms per token,    29.67 tokens per second)
# llama_print_timings:        eval time =  7389.88 ms /    16 runs   (  461.87 ms per token,     2.17 tokens per second)
# llama_print_timings:       total time =  9058.52 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.33 ms /    17 runs   (    0.96 ms per token,  1041.28 tokens per second)
# llama_print_timings: prompt eval time =  2356.68 ms /   206 tokens (   11.44 ms per token,    87.41 tokens per second)
# llama_print_timings:        eval time =  7016.84 ms /    16 runs   (  438.55 ms per token,     2.28 tokens per second)
# llama_print_timings:       total time =  9452.98 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =    16.57 ms /    17 runs   (    0.97 ms per token,  1026.14 tokens per second)
# llama_print_timings: prompt eval time =  3047.96 ms /   327 tokens (    9.32 ms per token,   107.28 tokens per second)
# llama_print_timings:        eval time =  7028.52 ms /    16 runs   (  439.28 ms per token,     2.28 tokens per second)
# llama_print_timings:       total time = 10156.30 ms

# %%
print("Time taken ",(end-start))
# Out:
# Time taken  193.0741159915924

# %%
data_3.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       model_response
# 0         {"Priority" : "High", "ETA" : "Immediate"}
# 1         {"Priority" : "High", "ETA" : "Immediate"}
# 2         {"Priority" : "High", "ETA" : "Immediate"}
# 3          {"Priority" : "Medium", "ETA" : "2 Days"}
# 4  {"Priority" : "Medium", "ETA" : "1 - 2 Busines...

# %%
i = 2
print(data_3.loc[i, 'support_ticket_text'])
# Out:
# I've accidentally deleted essential work documents, causing substantial data loss. I understand the need to avoid further actions on my device. Can you please prioritize the data recovery process and guide me through it?

# %%
print(data_3.loc[i, 'model_response'])
# Out:
# {"Priority" : "High", "ETA" : "Immediate"}

# %%
# Applying the function to the model response
data_3['model_response_parsed'] = data_3['model_response'].apply(extract_json_data)
data_3['model_response_parsed'].head()
# Out:
# 0             {'Priority': 'High', 'ETA': 'Immediate'}
# 1             {'Priority': 'High', 'ETA': 'Immediate'}
# 2             {'Priority': 'High', 'ETA': 'Immediate'}
# 3              {'Priority': 'Medium', 'ETA': '2 Days'}
# 4    {'Priority': 'Medium', 'ETA': '1 - 2 Business ...
# Name: model_response_parsed, dtype: object

# %%
# Normalizing the model_response_parsed column
model_response_parsed_df_3 = pd.json_normalize(data_3['model_response_parsed'])
model_response_parsed_df_3.head(21)
# Out:
#    Priority                  ETA
# 0      High            Immediate
# 1      High            Immediate
# 2      High            Immediate
# 3    Medium               2 Days
# 4    Medium  1 - 2 Business Days
# 5      High            Immediate
# 6      High            Immediate
# 7      High            Immediate
# 8      High            Immediate
# 9      High            Immediate
# 10     High            Immediate
# 11     High            Immediate
# 12     High            Immediate
# 13     High            Immediate
# 14     High            Immediate
# 15     High            Immediate
# 16     High            Immediate
# 17     High            Immediate
# 18     High            Immediate
# 19     High            Immediate
# 20     High            Immediate

# %%
# Concatinating two dataframes
data_with_parsed_model_output_3 = pd.concat([data_3, model_response_parsed_df_3], axis=1)
data_with_parsed_model_output_3.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       model_response  \
# 0         {"Priority" : "High", "ETA" : "Immediate"}
# 1         {"Priority" : "High", "ETA" : "Immediate"}
# 2         {"Priority" : "High", "ETA" : "Immediate"}
# 3          {"Priority" : "Medium", "ETA" : "2 Days"}
# 4  {"Priority" : "Medium", "ETA" : "1 - 2 Busines...
#
#                                model_response_parsed Priority  \
# 0           {'Priority': 'High', 'ETA': 'Immediate'}     High
# 1           {'Priority': 'High', 'ETA': 'Immediate'}     High
# 2           {'Priority': 'High', 'ETA': 'Immediate'}     High
# 3            {'Priority': 'Medium', 'ETA': '2 Days'}   Medium
# 4  {'Priority': 'Medium', 'ETA': '1 - 2 Business ...   Medium
#
#                    ETA
# 0            Immediate
# 1            Immediate
# 2            Immediate
# 3               2 Days
# 4  1 - 2 Business Days

# %%
# Dropping model_response and model_response_parsed columns
final_data_3 = data_with_parsed_model_output_3.drop(['model_response','model_response_parsed'], axis=1)
final_data_3.head()
# Out:
#   support_tick_id                                support_ticket_text Priority  \
# 0      ST2023-006  My internet connection has significantly slowe...     High
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...     High
# 2      ST2023-008  I've accidentally deleted essential work docum...     High
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...   Medium
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...   Medium
#
#                    ETA
# 0            Immediate
# 1            Immediate
# 2            Immediate
# 3               2 Days
# 4  1 - 2 Business Days

# %%
final_data_3 = pd.concat([final_data_3,final_data_2[["Category","Tags"]]],axis=1)

# %%
final_data_3 = final_data_3[["support_tick_id","support_ticket_text","Category","Tags","Priority","ETA"]]

# %%
final_data_3
# Out:
#    support_tick_id                                support_ticket_text  \
# 0       ST2023-006  My internet connection has significantly slowe...
# 1       ST2023-007  Urgent help required! My laptop refuses to sta...
# 2       ST2023-008  I've accidentally deleted essential work docum...
# 3       ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4       ST2023-010  My smartphone battery is draining rapidly, eve...
# 5       ST2023-011  I'm locked out of my online banking account an...
# 6       ST2023-012  My computer's performance is sluggish, severel...
# 7       ST2023-013  I'm experiencing a recurring blue screen error...
# 8       ST2023-014  My external hard drive isn't being recognized ...
# 9       ST2023-015  The graphics card in my gaming laptop seems to...
# 10      ST2023-016  I accidentally formatted my USB drive with cri...
# 11      ST2023-017  My computer's screen has gone black, and I can...
# 12      ST2023-018  I accidentally spilled water on my laptop, and...
# 13      ST2023-019  My USB flash drive is physically damaged, and ...
# 14      ST2023-020  The touchpad on my laptop has stopped working,...
# 15      ST2023-021  My internet connection is frequently dropping,...
# 16      ST2023-022  Wi-Fi is inconsistent despite proximity to the...
# 17      ST2023-023  I accidentally formatted my USB drive with cru...
# 18      ST2023-024  My external hard drive isn't being recognized,...
# 19      ST2023-025  I am experiencing a critical problem with my i...
# 20      ST2023-026  I hope this message finds you well. I am writi...
#
#              Category                                               Tags  \
# 0            Internet    [connection_issue, internet, slow_connectivity]
# 1      Hardware_issue                        [Hardware, laptop, startup]
# 2           Data Loss                                        [data_loss]
# 3         WiFi_Signal                                [WiFi, weak_signal]
# 4             Battery                        [smartphone, battery_drain]
# 5      Account_Access                   [Account_Access, Password_Reset]
# 6         Performance                  [performance_issue, productivity]
# 7   Technical_Support                       [BlueScreen, Hardware_Issue]
# 8            Hardware                        [Hard_drive, Data_recovery]
# 9            Hardware     [Graphics_card, gaming_laptop, hardware_issue]
# 10      Data Recovery                              [data_loss, recovery]
# 11    Technical_Issue                    [Screen_issue, Technical_Issue]
# 12           Hardware                   [laptop, water_damage, hardware]
# 13      Data Recovery                       [data_recovery, flash_drive]
# 14           Hardware                         [touchpad, hardware_issue]
# 15       Connectivity             [connection_issue, internet, dropping]
# 16       Connectivity                           [WiFi, connection_issue]
# 17      Data Recovery                         [data_loss, file_recovery]
# 18           Hardware                        [Hard_drive, Data_recovery]
# 19     Internet_Issue  [Internet_issue, connection_issue, slow_internet]
# 20     Software_Issue  [software_issue, application_freeze, unexplain...
#
#    Priority                  ETA
# 0      High            Immediate
# 1      High            Immediate
# 2      High            Immediate
# 3    Medium               2 Days
# 4    Medium  1 - 2 Business Days
# 5      High            Immediate
# 6      High            Immediate
# 7      High            Immediate
# 8      High            Immediate
# 9      High            Immediate
# 10     High            Immediate
# 11     High            Immediate
# 12     High            Immediate
# 13     High            Immediate
# 14     High            Immediate
# 15     High            Immediate
# 16     High            Immediate
# 17     High            Immediate
# 18     High            Immediate
# 19     High            Immediate
# 20     High            Immediate

# %% [markdown]
# ## **Task 4 - Creating a Draft Response**

# %%
data_4 = data.copy()

# %%
def response_4(prompt,ticket,category,tags,priority,eta):
    model_output = llm(
      f"""
      Q: {prompt}
      Support ticket: {ticket}
      Category : {category}
      Tags : {tags}
      Priority: {priority}
      ETA: {eta}
      A:
      """,
      max_tokens=1024, # setting the maximum number of tokens the model should generate for this task.
      stop=None,#["Q:", "\n"], # removing the stop so that the model would generate a complete response to the customers
      temperature=0.01, # setting the value for temperature.
      echo=False,
    )

    temp_output = model_output["choices"][0]["text"]


    return temp_output

# %%
prompt_4 = """
   You are an AI tasked with creating a draft response for support tickets.
   Please create a draft response based on the following criteria: Customer satisfaction, severity of issue, how much responsibility the company has for the issue.
   Please also be understanding, professional, helpful and to the point.
   Also please keep it under 200 words
"""

# %%
#Applying generate_llama_response function on support_ticket_text column
start = time.time()
data_4['model_response'] = final_data_3[['support_ticket_text','Category','Tags','Priority','ETA']].apply(lambda x: response_4(prompt_4, x[0],x[1],x[2],x[3],x[4]),axis=1)
end = time.time()
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   250.19 ms /   234 runs   (    1.07 ms per token,   935.28 tokens per second)
# llama_print_timings: prompt eval time =  1864.35 ms /   109 tokens (   17.10 ms per token,    58.47 tokens per second)
# llama_print_timings:        eval time = 108514.01 ms /   233 runs   (  465.73 ms per token,     2.15 tokens per second)
# llama_print_timings:       total time = 111667.01 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   219.81 ms /   211 runs   (    1.04 ms per token,   959.93 tokens per second)
# llama_print_timings: prompt eval time =  1784.89 ms /    90 tokens (   19.83 ms per token,    50.42 tokens per second)
# llama_print_timings:        eval time = 97879.09 ms /   210 runs   (  466.09 ms per token,     2.15 tokens per second)
# llama_print_timings:       total time = 100808.48 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   258.03 ms /   250 runs   (    1.03 ms per token,   968.87 tokens per second)
# llama_print_timings: prompt eval time =  1740.53 ms /    76 tokens (   22.90 ms per token,    43.66 tokens per second)
# llama_print_timings:        eval time = 115192.43 ms /   249 runs   (  462.62 ms per token,     2.16 tokens per second)
# llama_print_timings:       total time = 118302.36 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   281.27 ms /   271 runs   (    1.04 ms per token,   963.48 tokens per second)
# llama_print_timings: prompt eval time =  1786.69 ms /    96 tokens (   18.61 ms per token,    53.73 tokens per second)
# llama_print_timings:        eval time = 124808.61 ms /   270 runs   (  462.25 ms per token,     2.16 tokens per second)
# llama_print_timings:       total time = 128100.52 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   312.43 ms /   302 runs   (    1.03 ms per token,   966.63 tokens per second)
# llama_print_timings: prompt eval time =  1741.65 ms /    73 tokens (   23.86 ms per token,    41.91 tokens per second)
# llama_print_timings:        eval time = 139820.55 ms /   301 runs   (  464.52 ms per token,     2.15 tokens per second)
# llama_print_timings:       total time = 143257.70 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   290.27 ms /   273 runs   (    1.06 ms per token,   940.50 tokens per second)
# llama_print_timings: prompt eval time =  1724.96 ms /    65 tokens (   26.54 ms per token,    37.68 tokens per second)
# llama_print_timings:        eval time = 128687.18 ms /   272 runs   (  473.11 ms per token,     2.11 tokens per second)
# llama_print_timings:       total time = 131970.53 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   256.35 ms /   240 runs   (    1.07 ms per token,   936.23 tokens per second)
# llama_print_timings: prompt eval time =  1752.56 ms /    66 tokens (   26.55 ms per token,    37.66 tokens per second)
# llama_print_timings:        eval time = 113157.26 ms /   239 runs   (  473.46 ms per token,     2.11 tokens per second)
# llama_print_timings:       total time = 116273.68 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   307.35 ms /   289 runs   (    1.06 ms per token,   940.30 tokens per second)
# llama_print_timings: prompt eval time =  1737.11 ms /    71 tokens (   24.47 ms per token,    40.87 tokens per second)
# llama_print_timings:        eval time = 136574.56 ms /   288 runs   (  474.22 ms per token,     2.11 tokens per second)
# llama_print_timings:       total time = 139986.03 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   262.29 ms /   253 runs   (    1.04 ms per token,   964.57 tokens per second)
# llama_print_timings: prompt eval time =  1714.78 ms /    65 tokens (   26.38 ms per token,    37.91 tokens per second)
# llama_print_timings:        eval time = 117599.40 ms /   252 runs   (  466.66 ms per token,     2.14 tokens per second)
# llama_print_timings:       total time = 120732.32 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   265.30 ms /   258 runs   (    1.03 ms per token,   972.47 tokens per second)
# llama_print_timings: prompt eval time =  1749.30 ms /    80 tokens (   21.87 ms per token,    45.73 tokens per second)
# llama_print_timings:        eval time = 119210.79 ms /   257 runs   (  463.86 ms per token,     2.16 tokens per second)
# llama_print_timings:       total time = 122371.08 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   244.24 ms /   242 runs   (    1.01 ms per token,   990.84 tokens per second)
# llama_print_timings: prompt eval time =  1701.11 ms /    66 tokens (   25.77 ms per token,    38.80 tokens per second)
# llama_print_timings:        eval time = 110786.78 ms /   241 runs   (  459.70 ms per token,     2.18 tokens per second)
# llama_print_timings:       total time = 113780.72 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   290.80 ms /   280 runs   (    1.04 ms per token,   962.86 tokens per second)
# llama_print_timings: prompt eval time =  1745.03 ms /    75 tokens (   23.27 ms per token,    42.98 tokens per second)
# llama_print_timings:        eval time = 129510.30 ms /   279 runs   (  464.19 ms per token,     2.15 tokens per second)
# llama_print_timings:       total time = 132799.61 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   227.17 ms /   218 runs   (    1.04 ms per token,   959.63 tokens per second)
# llama_print_timings: prompt eval time =  1723.38 ms /    74 tokens (   23.29 ms per token,    42.94 tokens per second)
# llama_print_timings:        eval time = 99676.25 ms /   217 runs   (  459.34 ms per token,     2.18 tokens per second)
# llama_print_timings:       total time = 102579.05 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   259.68 ms /   253 runs   (    1.03 ms per token,   974.28 tokens per second)
# llama_print_timings: prompt eval time =  1628.55 ms /    62 tokens (   26.27 ms per token,    38.07 tokens per second)
# llama_print_timings:        eval time = 116731.97 ms /   252 runs   (  463.22 ms per token,     2.16 tokens per second)
# llama_print_timings:       total time = 119732.30 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   238.77 ms /   232 runs   (    1.03 ms per token,   971.66 tokens per second)
# llama_print_timings: prompt eval time =  1705.91 ms /    67 tokens (   25.46 ms per token,    39.28 tokens per second)
# llama_print_timings:        eval time = 106529.49 ms /   231 runs   (  461.17 ms per token,     2.17 tokens per second)
# llama_print_timings:       total time = 109482.01 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   264.76 ms /   258 runs   (    1.03 ms per token,   974.46 tokens per second)
# llama_print_timings: prompt eval time =  1609.42 ms /    59 tokens (   27.28 ms per token,    36.66 tokens per second)
# llama_print_timings:        eval time = 118251.41 ms /   257 runs   (  460.12 ms per token,     2.17 tokens per second)
# llama_print_timings:       total time = 121263.43 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   279.55 ms /   274 runs   (    1.02 ms per token,   980.14 tokens per second)
# llama_print_timings: prompt eval time =  1631.94 ms /    62 tokens (   26.32 ms per token,    37.99 tokens per second)
# llama_print_timings:        eval time = 126459.45 ms /   273 runs   (  463.22 ms per token,     2.16 tokens per second)
# llama_print_timings:       total time = 129581.71 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   256.83 ms /   251 runs   (    1.02 ms per token,   977.29 tokens per second)
# llama_print_timings: prompt eval time =  1618.96 ms /    59 tokens (   27.44 ms per token,    36.44 tokens per second)
# llama_print_timings:        eval time = 115325.88 ms /   250 runs   (  461.30 ms per token,     2.17 tokens per second)
# llama_print_timings:       total time = 118301.40 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   292.24 ms /   285 runs   (    1.03 ms per token,   975.23 tokens per second)
# llama_print_timings: prompt eval time =  1610.25 ms /    60 tokens (   26.84 ms per token,    37.26 tokens per second)
# llama_print_timings:        eval time = 129887.57 ms /   284 runs   (  457.35 ms per token,     2.19 tokens per second)
# llama_print_timings:       total time = 133048.44 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   224.87 ms /   224 runs   (    1.00 ms per token,   996.13 tokens per second)
# llama_print_timings: prompt eval time =  2315.11 ms /   219 tokens (   10.57 ms per token,    94.60 tokens per second)
# llama_print_timings:        eval time = 101284.50 ms /   223 runs   (  454.19 ms per token,     2.20 tokens per second)
# llama_print_timings:       total time = 104779.91 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  2060.21 ms
# llama_print_timings:      sample time =   227.85 ms /   227 runs   (    1.00 ms per token,   996.26 tokens per second)
# llama_print_timings: prompt eval time =  2970.78 ms /   340 tokens (    8.74 ms per token,   114.45 tokens per second)
# llama_print_timings:        eval time = 103599.47 ms /   226 runs   (  458.40 ms per token,     2.18 tokens per second)
# llama_print_timings:       total time = 107764.48 ms

# %%
print("Time taken",(end-start))
# Out:
# Time taken 2526.6263999938965

# %%
data_4.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       model_response
# 0   Dear Valued Customer,\n       \n       We apo...
# 1   Dear Valued Customer,\n        We understand ...
# 2   Dear Valued Customer,\n       \n       We are...
# 3   Dear Valued Customer,\n       \n       We apo...
# 4   Dear Valued Customer,\n       \n       We're ...

# %%
i = 2
print(data_4.loc[i, 'support_ticket_text'])
# Out:
# I've accidentally deleted essential work documents, causing substantial data loss. I understand the need to avoid further actions on my device. Can you please prioritize the data recovery process and guide me through it?

# %%
print(data_4.loc[i, 'model_response'])
# Out:
#  Dear Valued Customer,
#
#        We are deeply sorry for the inconvenience you have experienced due to the accidental deletion of essential work documents. We understand the severity of this issue and the impact it may have on your productivity. Our team is committed to prioritizing the data recovery process and will work diligently to help you regain access to your lost files as soon as possible.
#
#        In order to facilitate the data recovery process, please follow these steps:
#          1. Do not use your device for any further actions that may overwrite the deleted files.
#          2. Contact our technical support team at [support_email] or call us at [support_phone] to initiate the data recovery process.
#          3. Provide us with the necessary details about your device and the type of files that were lost.
#
#        We take full responsibility for this issue and will do everything in our power to help you recover your data as quickly and efficiently as possible. Please be assured that we value your business and are committed to ensuring your satisfaction.
#
#        Sincerely,
#        [Your Name]
#        [Company Name] Technical Support Team

# %%
final_data_4 = pd.concat([final_data_3,data_4["model_response"]],axis=1)

# %%
final_data_4.rename(columns={"model_response":"Response"},inplace=True)

# %%
final_data_4
# Out:
#    support_tick_id                                support_ticket_text  \
# 0       ST2023-006  My internet connection has significantly slowe...
# 1       ST2023-007  Urgent help required! My laptop refuses to sta...
# 2       ST2023-008  I've accidentally deleted essential work docum...
# 3       ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4       ST2023-010  My smartphone battery is draining rapidly, eve...
# 5       ST2023-011  I'm locked out of my online banking account an...
# 6       ST2023-012  My computer's performance is sluggish, severel...
# 7       ST2023-013  I'm experiencing a recurring blue screen error...
# 8       ST2023-014  My external hard drive isn't being recognized ...
# 9       ST2023-015  The graphics card in my gaming laptop seems to...
# 10      ST2023-016  I accidentally formatted my USB drive with cri...
# 11      ST2023-017  My computer's screen has gone black, and I can...
# 12      ST2023-018  I accidentally spilled water on my laptop, and...
# 13      ST2023-019  My USB flash drive is physically damaged, and ...
# 14      ST2023-020  The touchpad on my laptop has stopped working,...
# 15      ST2023-021  My internet connection is frequently dropping,...
# 16      ST2023-022  Wi-Fi is inconsistent despite proximity to the...
# 17      ST2023-023  I accidentally formatted my USB drive with cru...
# 18      ST2023-024  My external hard drive isn't being recognized,...
# 19      ST2023-025  I am experiencing a critical problem with my i...
# 20      ST2023-026  I hope this message finds you well. I am writi...
#
#              Category                                               Tags  \
# 0            Internet    [connection_issue, internet, slow_connectivity]
# 1      Hardware_issue                        [Hardware, laptop, startup]
# 2           Data Loss                                        [data_loss]
# 3         WiFi_Signal                                [WiFi, weak_signal]
# 4             Battery                        [smartphone, battery_drain]
# 5      Account_Access                   [Account_Access, Password_Reset]
# 6         Performance                  [performance_issue, productivity]
# 7   Technical_Support                       [BlueScreen, Hardware_Issue]
# 8            Hardware                        [Hard_drive, Data_recovery]
# 9            Hardware     [Graphics_card, gaming_laptop, hardware_issue]
# 10      Data Recovery                              [data_loss, recovery]
# 11    Technical_Issue                    [Screen_issue, Technical_Issue]
# 12           Hardware                   [laptop, water_damage, hardware]
# 13      Data Recovery                       [data_recovery, flash_drive]
# 14           Hardware                         [touchpad, hardware_issue]
# 15       Connectivity             [connection_issue, internet, dropping]
# 16       Connectivity                           [WiFi, connection_issue]
# 17      Data Recovery                         [data_loss, file_recovery]
# 18           Hardware                        [Hard_drive, Data_recovery]
# 19     Internet_Issue  [Internet_issue, connection_issue, slow_internet]
# 20     Software_Issue  [software_issue, application_freeze, unexplain...
#
#    Priority                  ETA  \
# 0      High            Immediate
# 1      High            Immediate
# 2      High            Immediate
# 3    Medium               2 Days
# 4    Medium  1 - 2 Business Days
# 5      High            Immediate
# 6      High            Immediate
# 7      High            Immediate
# 8      High            Immediate
# 9      High            Immediate
# 10     High            Immediate
# 11     High            Immediate
# 12     High            Immediate
# 13     High            Immediate
# 14     High            Immediate
# 15     High            Immediate
# 16     High            Immediate
# 17     High            Immediate
# 18     High            Immediate
# 19     High            Immediate
# 20     High            Immediate
#
#                                              Response
# 0    Dear Valued Customer,\n       \n       We apo...
# 1    Dear Valued Customer,\n        We understand ...
# 2    Dear Valued Customer,\n       \n       We are...
# 3    Dear Valued Customer,\n       \n       We apo...
# 4    Dear Valued Customer,\n       \n       We're ...
# 5    Dear Valued Customer,\n       \n       We're ...
# 6    Dear Valued Customer,\n       \n       We apo...
# 7    Dear Valued Customer,\n       \n       We're ...
# 8    Dear Valued Customer,\n       \n       We are...
# 9    Dear Valued Customer,\n       \n       We're ...
# 10   Dear Valued Customer,\n       \n       We are...
# 11   Dear Valued Customer,\n       \n       We are...
# 12   Dear Valued Customer,\n       \n       We are...
# 13   Dear Valued Customer,\n       \n       We are...
# 14   Dear Valued Customer,\n       \n       We are...
# 15   Dear Valued Customer,\n       \n       We are...
# 16   Dear Valued Customer,\n       \n       We apo...
# 17   Dear Valued Customer,\n       \n       We are...
# 18   Dear Valued Customer,\n       \n       We are...
# 19   Dear Valued Customer,\n       \n       We apo...
# 20   Dear Valued Customer,\n       \n       We apo...

# %% [markdown]
# ## **Model Output Analysis**

# %%
final_data = final_data_4.copy()

# %%
final_data['Category'].value_counts()
# Out:
# Hardware             5
# Data Recovery        3
# Connectivity         2
# Data Loss            1
# Internet             1
# Hardware_issue       1
# Account_Access       1
# Battery              1
# WiFi_Signal          1
# Technical_Support    1
# Performance          1
# Technical_Issue      1
# Internet_Issue       1
# Software_Issue       1
# Name: Category, dtype: int64

# %%
final_data["Priority"].value_counts()
# Out:
# High      19
# Medium     2
# Name: Priority, dtype: int64

# %%
final_data["ETA"].value_counts()
# Out:
# Immediate              19
# 2 Days                  1
# 1 - 2 Business Days     1
# Name: ETA, dtype: int64

# %% [markdown]
# Let's dive in a bit deeper here.

# %%
final_data.groupby(['Category', 'ETA']).support_tick_id.count()
# Out:
# Category           ETA
# Account_Access     Immediate              1
# Battery            1 - 2 Business Days    1
# Connectivity       Immediate              2
# Data Loss          Immediate              1
# Data Recovery      Immediate              3
# Hardware           Immediate              5
# Hardware_issue     Immediate              1
# Internet           Immediate              1
# Internet_Issue     Immediate              1
# Performance        Immediate              1
# Software_Issue     Immediate              1
# Technical_Issue    Immediate              1
# Technical_Support  Immediate              1
# WiFi_Signal        2 Days                 1
# Name: support_tick_id, dtype: int64

# %% [markdown]
# ## **Actionable Insights and Recommendations**

# %% [markdown]
# - Leveraging LLM's for support ticket categorizing seem a brilliant use case especially since these techniques think and work on par with human.
# - But we do have to careful when using such techniques as when we automate this process everything depends upon the LLM's response as well.
# - In this particular task it was not easy to make the model understand that I am expecting the output in JSON format even when we've explicitly provided
#     examples the model would generate category/tags/priority/eta for inital amount of queries but would skip the last 2 queries for some reason .
# - And we overcame such scenarios by providing more examples it was also important to keep the prompt consistent, if we mention support ticket / customer's comment the model didn't think of it as the same thing it gets confused and didn't output a response.
# - I would recommend using Llama 2.1 Instruct models for such tasks especially 13B Parameter model if you've the resource as it would provide more precise answers
